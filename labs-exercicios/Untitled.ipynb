# %%
import math
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,5,100)
y = math.e**x


plt.plot(x,y)

plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico da função y = e^x')

plt.show()
