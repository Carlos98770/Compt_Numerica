# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


dataFrame = pd.read_csv('./drive/MyDrive/CN/ProjetoCN/Dados/Dados2.csv')


t = dataFrame.iloc[:,0]
ut = dataFrame.iloc[:,1]
yt = dataFrame.iloc[:,2]

plt.plot(t,yt,label = 'Dados')
plt.show()

plt.scatter(t,yt,label = 'Dados')
plt.show()

print("===========================")

plt.plot(ut,yt,label = 'Dados')
plt.show()

plt.scatter(ut,yt,label = 'Dados')
plt.show()
